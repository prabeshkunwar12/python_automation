# %%
import re

# %%
# Search for the word "Python" in a string using []
print(re.search(r"[Pp]ython", "Python is a programming language."))
print(re.search(r"[a-zA-Z]ing", "Python is a programming language."))
# Out:
# <re.Match object; span=(0, 6), match='Python'>
# <re.Match object; span=(19, 23), match='ming'>

# %%
# Search for a pattern that does not match any letter using [^]
print(re.search(r"[^a-zA-Z]", "Python is a programming language."))
print(re.search(r"[^a-zA-Z ]", "Python Is A Programming Language."))
# Out:
# <re.Match object; span=(6, 7), match=' '>
# <re.Match object; span=(32, 33), match='.'>

# %%
# Search for words using |
print(re.search(r"Python|Java", "I love Python."))
print(re.search(r"Python|Java", "I love Java."))
print(re.search(r"Python|Java", "I love C++."))
# Out:
# <re.Match object; span=(7, 13), match='Python'>
# <re.Match object; span=(7, 11), match='Java'>
# None

# %%
# Search for a repetition pattern using .*
print(re.search(r"Py.*n", "Pygmalion")) # Matches "Pygmalion" because it starts with "Py" and ends with "n" with any characters in between
print(re.search(r"Py.*n", "Python Programming")) # Matches "Python Programmin" because it starts with "Py" and ends with "n" with any characters in between
print(re.search(r"Py[a-z]*n", "Python Programming")) # Matches "Python" because it starts with "Py", followed by zero or more lowercase letters, and ends with "n"
print(re.search(r"Py[a-z]*n", "Pyn")) # Matches "Pyn" because it starts with "Py", followed by zero lowercase letters, and ends with "n"
# Out:
# <re.Match object; span=(0, 9), match='Pygmalion'>
# <re.Match object; span=(0, 17), match='Python Programmin'>
# <re.Match object; span=(0, 6), match='Python'>
# <re.Match object; span=(0, 3), match='Pyn'>

# %%
# Search for a repetition pattern using +
print(re.search(r"o+l+", "goldfish")) # Matches "ol" because it has one or more 'o' followed by one or more 'l'
print(re.search(r"o+l+", "woolly")) # Matches "oolly" because it has one or more 'o' followed by one or more 'l'
print(re.search(r"o+l+", "boil")) # does not match because it does not have one or more 'o' followed by one or more 'l'
# Out:
# <re.Match object; span=(1, 3), match='ol'>
# <re.Match object; span=(1, 5), match='ooll'>
# None

# %%
# Search for a repetition pattern using ?
print(re.search(r"p?each", "To each their own")) # Matches "each" because 'p' is optional and "each" follows it
print(re.search(r"p?each", "I like peaches")) # Matches "peach" because 'p' is optional and "each" follows it
# Out:
# <re.Match object; span=(3, 7), match='each'>
# <re.Match object; span=(7, 12), match='peach'>

# %%
print(re.search(r".com", "welcome")) # Matches "lcome" because the dot is treated as a wildcard character that matches any character, so it looks for "m" followed by any character followed by "com", which is present in "welcome"
print(re.search(r".com", "mydomain.com")) # Matches ".com" because the dot is treated as a wildcard character that matches any character, so it looks for "m" followed by any character followed by "com", which is present in "mydomain.com"
print(re.search(r"\.com", "welcome")) # does not match because the backslash escapes the dot, so it looks for the literal string ".com", which is not present in "welcome"
print(re.search(r"\.com", "mydomain.com")) # Matches "mydomain.com" because the backslash escapes the dot, so it looks for the literal string ".com", which is present in "mydomain.com"
# Out:
# <re.Match object; span=(2, 6), match='lcom'>
# <re.Match object; span=(8, 12), match='.com'>
# None
# <re.Match object; span=(8, 12), match='.com'>

# %%
print(re.search(r"A.*a", "Argentina")) # Matches "Argentina" because it starts with "A" and ends with "a" with any characters in between
print(re.search(r"A.*a", "Azerbaijan")) # Matches "Azerbaija" because it starts with "A" and ends with "a" with any characters in between
print(re.search(r"^A.*a$", "Australia")) # Matches "Australia" because it starts with "A" and ends with "a" with any characters in between 
print(re.search(r"^A.*a$", "Azerbaijan")) # does not match because it does not end with "a"
# Out:
# <re.Match object; span=(0, 9), match='Argentina'>
# <re.Match object; span=(0, 9), match='Azerbaija'>
# <re.Match object; span=(0, 9), match='Australia'>
# None

# %%
# Explanation of the pattern for valid variable names in Python
# The pattern "^[a-zA-Z_][a-zA-Z0-9_]*$" can be broken down as follows:
# ^ asserts the start of the string
# [a-zA-Z_] matches any letter (uppercase or lowercase) or an underscore, which is the first character of a valid variable name
# [a-zA-Z0-9_]* matches zero or more letters, digits, or underscores, which can follow the first character in a valid variable name
# $ asserts the end of the string
# anchors '^' and '$' will take entire string into account rather than individual words in the string
pattern = r"^[a-zA-Z_][a-zA-Z0-9_]*$"
print(re.search(pattern, "_this_is_a_valid_variable_name"))
print(re.search(pattern, "this isn't a valid variable"))
print(re.search(pattern, "my_variable1"))
print(re.search(pattern, "2my_variable1"))
# Out:
# <re.Match object; span=(0, 30), match='_this_is_a_valid_variable_name'>
# None
# <re.Match object; span=(0, 12), match='my_variable1'>
# None

# %%
def check_web_address(text):
  pattern = r"^(www\.)?[\w|\.|\-|\+]*(\.\w*)$"
  result = re.search(pattern, text)
  return result != None

print(check_web_address("gmail.com")) # True
print(check_web_address("www@google")) # False
print(check_web_address("www.Coursera.org")) # True
print(check_web_address("web-address.com/homepage")) # False
print(check_web_address("My_Favorite-Blog.US")) # True
# Out:
# True
# False
# True
# False
# True

# %%
def check_time(text):
  pattern = r"[1-9][0-2]?:[0-5][0-9]( )?[AM|PM|am|pm]"
  result = re.search(pattern, text)
  return result != None

print(check_time("12:45pm")) # True
print(check_time("9:59 AM")) # True
print(check_time("6:60am")) # False
print(check_time("five o'clock")) # False
print(check_time("6:02 am")) # True
print(check_time("6:02km")) # False
# Out:
# True
# True
# False
# False
# True
# False

# %%
def contains_acronym(text):
  pattern = r"\([\d|A-Z]\w*\)" 
  result = re.search(pattern, text)
  return result != None

print(contains_acronym("Instant messaging (IM) is a set of communication technologies used for text-based communication")) # True
print(contains_acronym("American Standard Code for Information Interchange (ASCII) is a character encoding standard for electronic communication")) # True
print(contains_acronym("Please do NOT enter without permission!")) # False
print(contains_acronym("PostScript is a fourth-generation programming language (4GL)")) # True
print(contains_acronym("Have fun using a self-contained underwater breathing apparatus (Scuba)!")) # True
# Out:
# True
# True
# False
# True
# True

# %%
def correct_function(text):
  result = re.search(r" \d\d\d\d\d(-\d\d\d\d)?", text)  # Corrected regex pattern with space
  return result is not None

def check_zip_code(text):
  return correct_function(text)  # Call the correct_function

# Call the check_zip_code function with test cases
print(check_zip_code("The zip codes for New York are 10001 thru 11104."))  # True
print(check_zip_code("90210 is a TV show"))  # False (no space before 90210)
print(check_zip_code("Their address is: 123 Main Street, Anytown, AZ 85258-0001."))  # True
print(check_zip_code("The Parliament of Canada is at 111 Wellington St, Ottawa, ON K1A0A9."))  # False
# Out:
# True
# False
# True
# False

# %%
def rearrange_name(name):
    result = re.search(r"^([\w \.-]*), ([\w \.-]*)$", name)
    if result == None:
        return name
    return "{} {}".format(result[2], result[1])
rearrange_name("Hopper, Grace M.")
# Out:
# 'Grace M. Hopper'

# %%
def exactly_five_letter_word(text):
    result = re.findall(r"\b\w{5}\b", text)
    return result
def between_three_and_five_letter_word(text):
    result = re.findall(r"\b\w{3,5}\b", text)
    return result
def more_than_five_letter_word(text):
    result = re.findall(r"\b\w{6,}\b", text)
    return result
def at_most_five_letter_word(text):
    result = re.findall(r"\b\w{1,5}\b", text)
    return result
print(exactly_five_letter_word("These are some words: cat, dog, house, tree, and apple."))
print(between_three_and_five_letter_word("These are some words: cat, dog, house, tree, and apple."))
print(more_than_five_letter_word("answering machine learning questions on Coursera is fun!"))
print(at_most_five_letter_word("These are some words: cat, dog, house, tree, and apple."))
# Out:
# ['These', 'words', 'house', 'apple']
# ['These', 'are', 'some', 'words', 'cat', 'dog', 'house', 'tree', 'and', 'apple']
# ['answering', 'machine', 'learning', 'questions', 'Coursera']
# ['These', 'are', 'some', 'words', 'cat', 'dog', 'house', 'tree', 'and', 'apple']

# %%
def extract_pid(log_line):
    regex = r"\[(\d+)\]"
    result = re.search(regex, log_line)
    if result is None:
        return ""
    return result[1]

log_line = 'ERROR 2013-09-13 10:14:32,615 [12345] Something bad happened'
bad_log_line = 'ERROR 2013-09-13 10:14:32,615 Something bad happened'
print(extract_pid(log_line))
print(extract_pid(bad_log_line))
# Out:
# 12345

# %%
print(re.split(r"[.?!]", "One sentence. Another one? And the last one!"))
print(re.split(r"([.?!])", "One sentence. Another one? And the last one!"))
print(re.sub(r"[\w.%+-]+@[\w.-]+", "[REDACTED]", "Received an email for go_nuts95@my.example.com"))
print(re.sub(r"^([\w .-]*), ([\w .-]*)$", r"\2 \1", "Lovelace, Ada"))
# Out:
# ['One sentence', ' Another one', ' And the last one', '']
# ['One sentence', '.', ' Another one', '?', ' And the last one', '!', '']
# Received an email for [REDACTED]
# Ada Lovelace

# %%
def transform_record(record):
  new_record = re.sub(r"([\w .-]+),([\d-]+),([\w .-]+)", r"\1,+1-\2,\3", record)
  return new_record

print(transform_record("Sabrina Green,802-867-5309,System Administrator")) 
# Sabrina Green,+1-802-867-5309,System Administrator

print(transform_record("Eli Jones,684-3481127,IT specialist")) 
# Eli Jones,+1-684-3481127,IT specialist

print(transform_record("Melody Daniels,846-687-7436,Programmer")) 
# Melody Daniels,+1-846-687-7436,Programmer

print(transform_record("Charlie Rivera,698-746-3357,Web Developer")) 
# Charlie Rivera,+1-698-746-3357,Web Developer
# Out:
# Sabrina Green,+1-802-867-5309,System Administrator
# Eli Jones,+1-684-3481127,IT specialist
# Melody Daniels,+1-846-687-7436,Programmer
# Charlie Rivera,+1-698-746-3357,Web Developer

# %%
def multi_vowel_words(text):
  pattern = r"\b[a-zA-Z]*[aeiouAEIOU]{3}[a-zA-Z]*\b"
  result = re.findall(pattern, text)
  return result

print(multi_vowel_words("Life is beautiful")) 
# ['beautiful']

print(multi_vowel_words("Obviously, the queen is courageous and gracious.")) 
# ['Obviously', 'queen', 'courageous', 'gracious']

print(multi_vowel_words("The rambunctious children had to sit quietly and await their delicious dinner.")) 
# ['rambunctious', 'quietly', 'delicious']

print(multi_vowel_words("The order of a data queue is First In First Out (FIFO)")) 
# ['queue']

print(multi_vowel_words("Hello world!")) 
# []
# Out:
# ['beautiful']
# ['Obviously', 'queen', 'courageous', 'gracious']
# ['rambunctious', 'quietly', 'delicious']
# ['queue']
# []

# %%
# convert comments in code from Python style to C++ style
def transform_comments(line_of_code):
  result = re.sub(r"#+(.*)", r"//\1", line_of_code)
  return result

print(transform_comments("### Start of program")) 
# Should be "// Start of program"
print(transform_comments("  number = 0   ## Initialize the variable")) 
# Should be "  number = 0   // Initialize the variable"
print(transform_comments("  number += 1   # Increment the variable")) 
# Should be "  number += 1   // Increment the variable"
print(transform_comments("  return(number)")) 
# Should be "  return(number)"
# Out:
# // Start of program
#   number = 0   // Initialize the variable
#   number += 1   // Increment the variable
#   return(number)

# %%
# The convert_phone_number() function checks for a U.S. phone number format: XXX-XXX-XXXX (3 digits followed by a dash, 3 more digits followed by a dash, and 4 digits), and converts it to a more formal format that looks like this: (XXX) XXX-XXXX.
def convert_phone_number(phone):
  result = re.sub(r"(\b\d{3})-(\d{3})-(\d{4})\b", r"(\1) \2-\3", phone)  # Corrected regex pattern with capturing groups
  return result

print(convert_phone_number("My number is 212-345-9999.")) # My number is (212) 345-9999.
print(convert_phone_number("Please call 888-555-1234")) # Please call (888) 555-1234
print(convert_phone_number("123-123-12345")) # 123-123-12345
print(convert_phone_number("Phone number of Buckingham Palace is +44 303 123 7300")) # Phone number of Buckingham Palace is +44 303 123 7300
# Out:
# My number is (212) 345-9999.
# Please call (888) 555-1234
# 123-123-12345
# Phone number of Buckingham Palace is +44 303 123 7300

# %%
def find_gov_urls(website):
 pattern = r"\bhttps://www\.\w*\.gov\b" #enter the regex pattern here
 result = re.findall(pattern, website) #enter the re method here
 return result


print(find_gov_urls("https://www.data.gov is a great place to find open source datasets!")) # Should return ['https://www.data.gov']
print(find_gov_urls("Learn more about US National Parks at https://www.nps.gov, https://www.nationalparks.org, or https://www.recreation.gov.")) # Should return ['https://www.nps.gov', 'https://www.recreation.gov']
print(find_gov_urls("The Library of Congress (https://www.loc.gov) is an incredible resource!")) # Should return ['https://www.loc.gov']
print(find_gov_urls("The Library of Congress (www.loc.gov) is an incredible resource!")) # Should return []
# Out:
# ['https://www.data.gov']
# ['https://www.nps.gov', 'https://www.recreation.gov']
# ['https://www.loc.gov']
# []

# %%
def parse_city_country(text):
  pattern = r"[,.]" #enter the regex pattern here
  result = re.split(pattern, text) #enter the re method  here
  if len(result) != 2:
    return ""
  return result[0]#return the correct capturing group

print(parse_city_country("Paris, France")) # should return Paris
print(parse_city_country("Mumbai, India")) # should return Mumbai
print(parse_city_country("Rio de Janeiro. Brazil")) # should return Rio de Janeiro
print(parse_city_country("Tokyo! Japan"))  # result should be blank
# Out:
# Paris
# Mumbai
# Rio de Janeiro

# %%
def find_eid(report):
  pattern = r"\b[A-Z]-[\d]{7,8}\b" #enter the regex pattern here
  result = re.findall(pattern, report) #enter the re method  here
  return result


print(find_eid("Employees B-1234567 and C-12345678 worked with products X-123456 and Z-123456789")) # Should return ['B-1234567', 'C-12345678']
print(find_eid("Employees B-1234567 and C-12345678, not employees b-1234567 and c-12345678")) #Should return ['B-1234567', 'C-12345678']
# Out:
# ['B-1234567', 'C-12345678']
# ['B-1234567', 'C-12345678']
